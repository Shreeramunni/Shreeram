# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeramunni/Shreeram/blob/master/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Detection with OpenCV

# %%
# import necessary packages
import cv2
from google.colab.patches import cv2_imshow

# %%
# download the haar cascade file for frontal face detector
# !wget https://github.com/arunponnusamy/face-detection-comparison/raw/master/haarcascade_frontalface_default.xml
# Out:
# --2020-01-18 06:47:36--  https://github.com/arunponnusamy/face-detection-comparison/raw/master/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/arunponnusamy/face-detection-comparison/master/haarcascade_frontalface_default.xml [following]
# --2020-01-18 06:47:36--  https://raw.githubusercontent.com/arunponnusamy/face-detection-comparison/master/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.05s
#
# 2020-01-18 06:47:36 (16.4 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
# initialize face detector
face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
# !wget https://previews.123rf.com/images/alphaspirit/alphaspirit1504/alphaspirit150400118/38665682-simple-young-man-face-smiling-and-optimistic.jpg -O face.jpg
# !ls
# Out:
# --2020-01-18 06:57:40--  https://previews.123rf.com/images/alphaspirit/alphaspirit1504/alphaspirit150400118/38665682-simple-young-man-face-smiling-and-optimistic.jpg
# Resolving previews.123rf.com (previews.123rf.com)... 23.2.228.103
# Connecting to previews.123rf.com (previews.123rf.com)|23.2.228.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 198858 (194K) [image/jpeg]
# Saving to: ‘face.jpg’
#
# face.jpg            100%[===================>] 194.20K  --.-KB/s    in 0.01s
#
# 2020-01-18 06:57:40 (13.0 MB/s) - ‘face.jpg’ saved [198858/198858]
#
# face.jpg  haarcascade_frontalface_default.xml  sample_data

# %%
# process input image
image = cv2.imread('face.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# run the detector 
faces = face_detector.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[369 309 531 531]]

# %%
# loop through detected faces and draw rectangle
for (x,y,w,h) in faces:
  cv2.rectangle(image, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
# display output
#cv2.imshow("face detection - opencv haar", image)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1294x1300 at 0x7F317C31A7F0>
